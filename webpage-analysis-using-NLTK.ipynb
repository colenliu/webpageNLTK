# %%
# import nltk statement
import nltk

# %% [markdown]
# **identify what the webpage is about using NLTK in python**
#
# First, will grab webpage + analyze text to see what page is about, urllib module will help us to **crawl webpage**

# %%
# import urllib statement
import urllib.request

# create new response variable that opens up a link (crawl webpage)
response = urllib.request.urlopen('https://en.wikipedia.org/wiki/SpaceX')

# read html from webpage
html = response.read()

# print
print(html)
# Out:
# b'\n<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>SpaceX - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"XpYTagpAAL8AAqGmhy0AAACG","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"SpaceX","wgTitle":"SpaceX","wgCurRevisionId":950652157,"wgRevisionId":950652157,"wgArticleId":832774,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: BOT: original-url status unknown","CS1 maint: unfit url","CS1 French-language sources (fr)","Articles with short description","Use American English from August 2019","All Wikipedia 
# ...

# %% [markdown]
# It is clear that our webpage is about SpaceX, lets see if our code is able to correctly identify page's context.
#
# We will use **Beautiful Soup** which is a python library for pulling data out of HTML and XML files. We will use beautiful soup to clean out webpage text of HTML tags

# %%
# import statement
from bs4 import BeautifulSoup

# create new variable, soup, that uses beautifulsoup to pull data out of html files
soup = BeautifulSoup(html, 'html5lib')

# create new variable, text, that gets wanted data from soup variable 
text = soup.get_text(strip = True)

# print
print(text)
# Out:
# SpaceX - Wikipediadocument.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"XpYTagpAAL8AAqGmhy0AAACG","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"SpaceX","wgTitle":"SpaceX","wgCurRevisionId":950652157,"wgRevisionId":950652157,"wgArticleId":832774,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: BOT: original-url status unknown","CS1 maint: unfit url","CS1 French-language sources (fr)","Articles with short description","Use American English from August 2019","All Wikipedia articles written in American English","Use mdy dates from August 2019","Coordinates not on Wikidata",
# ...

# %% [markdown]
# now that we have clean text from **crawled web page**, convert text into **tokens**

# %%
# convert text into tokens
tokens = [t for t in text.split()]

# print tokens
print(tokens)
# Out:
# ['SpaceX', '-', 'Wikipediadocument.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"XpYTagpAAL8AAqGmhy0AAACG","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"SpaceX","wgTitle":"SpaceX","wgCurRevisionId":950652157,"wgRevisionId":950652157,"wgArticleId":832774,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1', 'maint:', 'BOT:', 'original-url', 'status', 'unknown","CS1', 'maint:', 'unfit', 'url","CS1', 'French-language', 'sources', '(fr)","Articles', 'with', 'short', 'description","Use', 'American', 'English', 'from', 'August', '2019","All', 'Wikipedia', 'articles', 'written', 'in', 'American', 'English","Use',
# ...

# %% [markdown]
# **COUNT WORD FREQUENCY**
#
# NLTK offers func: FreqDist() that does this for us. Also, remove stop words (a, at, the, for, etc.) from our web page as we don't need them to hamper our word frequency count. We will plot graph for most frequently occuring words in the webpage in order to get clear pic of context of webpage

# %%
# import stopwords statement
import nltk
nltk.download('stopwords')

# set sr variable to stopwords English
sr = stopwords.words('english')

# original list of tokens
clean_tokens = tokens[:]

# for loop to remove stop words
for token in tokens:
    if token in stopwords.words('english'):
        clean_tokens.remove(token)

# freq is new variable for frequency distribution of cleaned tokens
freq = nltk.FreqDist(clean_tokens)
for key,val in freq.items():
    print(str(key) + ':' + str(val))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\liuco\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# SpaceX:172
# -:14
# Wikipediadocument.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"XpYTagpAAL8AAqGmhy0AAACG","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"SpaceX","wgTitle":"SpaceX","wgCurRevisionId":950652157,"wgRevisionId":950652157,"wgArticleId":832774,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1:1
# maint::15
# BOT::12
# original-url:12
# status:12
# unknown","CS1:1
# unfit:3
# url","CS1:1
# French-language:2
# sources:5
# ...

# %%
# frequency plot of most frequently occuring words in webpage
freq.plot(20, cumulative = False)
